# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import matplotlib.pyplot as plt
import seaborn as sns

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))
# Out:
# /kaggle/input/videogames-sales-dataset/Video_Games_Sales_as_at_22_Dec_2016.csv
# /kaggle/input/videogames-sales-dataset/PS4_GamesSales.csv
# /kaggle/input/videogames-sales-dataset/XboxOne_GameSales.csv

# %%
data = pd.read_csv('data/PS4_GamesSales.csv',encoding = 'windows-1252')

# %%
data.columns
# Out:
# Index(['Game', 'Year', 'Genre', 'Publisher', 'North America', 'Europe',
#        'Japan', 'Rest of World', 'Global'],
#       dtype='object')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1034 entries, 0 to 1033
# Data columns (total 9 columns):
# Game             1034 non-null object
# Year             825 non-null float64
# Genre            1034 non-null object
# Publisher        825 non-null object
# North America    1034 non-null float64
# Europe           1034 non-null float64
# Japan            1034 non-null float64
# Rest of World    1034 non-null float64
# Global           1034 non-null float64
# dtypes: float64(6), object(3)
# memory usage: 72.8+ KB

# %%
data.head(10)
# Out:
#                              Game    Year             Genre  \
# 0              Grand Theft Auto V  2014.0            Action
# 1       Call of Duty: Black Ops 3  2015.0           Shooter
# 2           Red Dead Redemption 2  2018.0  Action-Adventure
# 3              Call of Duty: WWII  2017.0           Shooter
# 4                         FIFA 18  2017.0            Sports
# 5                         FIFA 17  2016.0            Sports
# 6                 Uncharted (PS4)  2016.0            Action
# 7                Spider-Man (PS4)  2018.0  Action-Adventure
# 8  Call of Duty: Infinite Warfare  2016.0           Shooter
# 9                       Fallout 4  2015.0      Role-Playing
#
#                         Publisher  North America  Europe  Japan  \
# 0                  Rockstar Games           6.06    9.71   0.60
# 1                      Activision           6.18    6.05   0.41
# 2                  Rockstar Games           5.26    6.21   0.21
# 3                      Activision           4.67    6.21   0.40
# 4                       EA Sports           1.27    8.64   0.15
# 5                 Electronic Arts           1.26    7.95   0.12
# 6  Sony Interactive Entertainment           4.49    3.93   0.21
# 7  Sony Interactive Entertainment           3.64    3.39   0.32
# 8                      Activision           3.11    3.83   0.19
# 9              Bethesda Softworks           2.91    3.97   0.27
#
#    Rest of World  Global
# 0           3.02   19.39
# 1           2.44   15.09
# 2           2.26   13.94
# 3           2.12   13.40
# 4           1.73   11.80
# 5           1.61   10.94
# 6           1.70   10.33
# 7           1.41    8.76
# 8           1.36    8.48
# 9           1.34    8.48

# %%
data.tail(10)
# Out:
#                                     Game    Year         Genre  \
# 1024                           Biomutant  2018.0        Action
# 1025                           Biomutant  2019.0        Action
# 1026                             de Blob  2017.0      Platform
# 1027                    Chaos on Deponia  2017.0     Adventure
# 1028                           Code Vein  2018.0        Action
# 1029  Fallen Legion: Flames of Rebellion     NaN  Role-Playing
# 1030            Radial G Racing Revolved  2017.0        Racing
# 1031                The Mummy Demastered     NaN        Action
# 1032          Project Nimbus: Code Mirai     NaN        Action
# 1033                 Battle Chef Brigade     NaN        Action
#
#                        Publisher  North America  Europe  Japan  Rest of World  \
# 1024                  THQ Nordic            0.0     0.0    0.0            0.0
# 1025                  THQ Nordic            0.0     0.0    0.0            0.0
# 1026                  THQ Nordic            0.0     0.0    0.0            0.0
# 1027      Daedalic Entertainment            0.0     0.0    0.0            0.0
# 1028  Bandai Namco Entertainment            0.0     0.0    0.0            0.0
# 1029                         NaN            0.0     0.0    0.0            0.0
# 1030               Tammeka Games            0.0     0.0    0.0            0.0
# 1031                         NaN            0.0     0.0    0.0            0.0
# 1032                         NaN            0.0     0.0    0.0            0.0
# 1033                         NaN            0.0     0.0    0.0            0.0
#
#       Global
# 1024     0.0
# 1025     0.0
# 1026     0.0
# 1027     0.0
# 1028     0.0
# 1029     0.0
# 1030     0.0
# 1031     0.0
# 1032     0.0
# 1033     0.0

# %%
data.Publisher.unique()
# Out:
# array(['Rockstar Games', 'Activision', 'EA Sports', 'Electronic Arts',
#        'Sony Interactive Entertainment', 'Bethesda Softworks',
#        'Sony Computer Entertainment', 'Namco Bandai Games', 'Square Enix',
#        'Capcom', 'Blizzard Entertainment', 'Ubisoft',
#        'Warner Bros. Interactive', '2K Sports',
#        'Warner Bros. Interactive Entertainment',
#        'Konami Digital Entertainment', '2K Games', 'Hello Games',
#        '505 Games', 'Deep Silver', 'Take-Two Interactive',
#        'Bandai Namco Games', 'Sega', 'Tecmo Koei', 'Gearbox Software',
#        'Mojang', 'Disney Interactive Studios', 'Focus Home Interactive',
#        'Studio Wildcard', 'Codemasters', 'Koch Media',
#        'Harmonix Music Systems', 'Rebellion Developments', 'Gun Media',
#        'Telltale Games', 'Kalypso Media', 'City Interactive',
#        'NIS America', 'Sold Out', 'Tripwire Interactive', 'PQube',
#        'THQ Nordic', 'Milestone S.r.l.', 'Nordic Games', 'Astragon',
#        'Koei Tecmo', 'Frontier Developments', 'Marvelous Interactive',
#        'Arc System Works', 'Milestone', 'Milestone S.r.l', 'System 3',
#        'Paradox InteractiveÊ', 'Dusenberry Martin Racing',
#        'Insomniac Games', 'Idea Factory International',
#        'Yacht Club Games', 'Little Orbit', 'Ravenscourt', 'Maximum Games',
#        'Acquire', 'Bigben Interactive', 'Atlus',
#        'Nihon Falcom Corporation', 'Tru Blu Entertainment', 'GameTrust',
#        'Grey Box', 'D3Publisher', 'Devolver Digital', nan, 'Gaijinworks',
#        'Funbox Media', 'Microids', 'Xseed Games', 'Badland Studio',
#        'GameMill', 'Nippon Ichi Software', 'Aksys Games',
#        'Revolution Software', 'Games Workshop', 'Atari', 'Nicalis',
#        'Ready at Dawn', 'Big Ben Interactive', 'Accolade', 'Soedesco',
#        'Team17 Digital Ltd', 'Introversion Software', 'Rising Star Games',
#        'Outright Games', 'Alternative Software', 'Nighthawk Interactive',
#        'Compile Heart', 'MLB.com', 'Techland', 'Avanquest', 'Merge Games',
#        'CokeM Interactive', '5pb', 'Perp Games', 'UFO Interactive',
#        'Wired Productions', 'Kadokawa Games', 'Yeti', 'Sprite',
#        'PM Studios', 'Gunho Online Entertainment',
#        'GameMill Entertainment', 'Stainless Games', 'League of Geeks',
#        'Mediascape', 'Rebellion', 'GungHo', 'TopWare Interactive', 'M2',
#        'UIG Entertainment', 'Active Gaming Media', 'Rain Games',
#        'Team17 Software', 'Team Meat', 'Thekla, Inc.', 'Entergram',
#        'DMM Games', 'Two Tribes', 'Spike Chunsoft',
#        'Perfect World Entertainment', 'BioWare',
#        'Sony Online Entertainment', 'Unknown', 'Taleworlds',
#        'DTP Entertainment', 'CD Projekt Red Studio', 'Compulsion Games',
#        'FarSight Studios', 'Futurlab 1', 'Level 5', 'Nowhere Studios',
#        'Frictional Games', 'Renegade Kid', 'Triniti Interactive',
#        '3D Realms', 'Endnight Games LtdÊ', 'Versus Evil',
#        'The Astronauts', 'Ice-pick Lodge', 'Double Damage Games',
#        'Wander MMO', 'Gust', 'Sinxsoft', 'Cygames',
#        'Daedalic Entertainment', 'Bandai Namco Entertainment',
#        'Tammeka Games'], dtype=object)

# %%
data.Genre.unique()
# Out:
# array(['Action', 'Shooter', 'Action-Adventure', 'Sports', 'Role-Playing',
#        'Misc', 'Platform', 'Racing', 'Fighting', 'Adventure', 'MMO',
#        'Simulation', 'Music', 'Party', 'Strategy', 'Puzzle',
#        'Visual Novel'], dtype=object)

# %%
plt.subplots(figsize = (10,7))
plt.hist(data.Year,bins = 30)
plt.show()
# Out:
# /opt/conda/lib/python3.6/site-packages/numpy/lib/histograms.py:824: RuntimeWarning: invalid value encountered in greater_equal
#   keep = (tmp_a >= first_edge)
# /opt/conda/lib/python3.6/site-packages/numpy/lib/histograms.py:825: RuntimeWarning: invalid value encountered in less_equal
#   keep &= (tmp_a <= last_edge)

# %%
rockstar = data[data.Publisher == 'Rockstar Games']
activision = data[data.Publisher == 'Activision']
sony = data[data.Publisher == 'Sony Interactive Entertainment']
bethesda = data[data.Publisher == 'Bethesda Softworks']

# %%
rockstar.head()
# Out:
#                       Game    Year             Genre       Publisher  \
# 0       Grand Theft Auto V  2014.0            Action  Rockstar Games
# 2    Red Dead Redemption 2  2018.0  Action-Adventure  Rockstar Games
# 197             L.A. Noire  2017.0         Adventure  Rockstar Games
#
#      North America  Europe  Japan  Rest of World  Global
# 0             6.06    9.71   0.60           3.02   19.39
# 2             5.26    6.21   0.21           2.26   13.94
# 197           0.18    0.32   0.00           0.10    0.60

# %%
plt.subplots(figsize = (10,5))
plt.hist(rockstar.Game)
plt.show()

# %%
plt.scatter(rockstar.Year,rockstar['North America'],color = 'red',alpha = 0.5)
plt.xlabel('Year')
plt.ylabel('North America Sale')
plt.show()

# %%
activision.head(20)
# Out:
#                                         Game    Year             Genre  \
# 1                  Call of Duty: Black Ops 3  2015.0           Shooter
# 3                         Call of Duty: WWII  2017.0           Shooter
# 8             Call of Duty: Infinite Warfare  2016.0           Shooter
# 12            Call of Duty: Advanced Warfare  2014.0           Shooter
# 19                                   Destiny  2014.0           Shooter
# 23           Crash Bandicoot N. Sane Trilogy  2017.0          Platform
# 30                      Call of Duty: Ghosts  2013.0           Shooter
# 32                                 Destiny 2  2017.0           Shooter
# 73                   Destiny: The Taken King  2015.0           Shooter
# 119                         Guitar Hero Live  2015.0             Music
# 166                  Destiny: The Collection  2016.0           Shooter
# 199  Call of Duty: Modern Warfare Remastered  2017.0           Shooter
# 206          The Amazing Spider-Man 2 (2014)  2014.0  Action-Adventure
# 214                    Skylanders: Trap Team  2014.0          Platform
# 227                                 Deadpool  2015.0            Action
# 233                Skylanders: SuperChargers  2015.0  Action-Adventure
# 238                    Skylanders SWAP Force  2013.0              Misc
# 239                   Skylanders Imaginators  2016.0          Platform
# 308                Transformers: Devastation  2015.0            Action
# 314                 Tony Hawk's Pro Skater 5  2015.0            Sports
#
#       Publisher  North America  Europe  Japan  Rest of World  Global
# 1    Activision           6.18    6.05   0.41           2.44   15.09
# 3    Activision           4.67    6.21   0.40           2.12   13.40
# 8    Activision           3.11    3.83   0.19           1.36    8.48
# 12   Activision           2.84    3.34   0.14           1.22    7.53
# 19   Activision           2.53    2.13   0.16           0.94    5.76
# 23   Activision           1.09    2.92   0.07           0.74    4.83
# 30   Activision           1.79    1.64   0.05           0.69    4.17
# 32   Activision           1.92    1.44   0.10           0.69    4.14
# 73   Activision           0.97    0.80   0.05           0.36    2.18
# 119  Activision           0.52    0.49   0.00           0.20    1.21
# 166  Activision           0.24    0.40   0.02           0.12    0.78
# 199  Activision           0.17    0.30   0.03           0.09    0.58
# 206  Activision           0.20    0.26   0.02           0.09    0.56
# 214  Activision           0.25    0.18   0.00           0.09    0.52
# 227  Activision           0.26    0.13   0.00           0.08    0.47
# 233  Activision           0.29    0.09   0.00           0.08    0.45
# 238  Activision           0.23    0.14   0.00           0.08    0.44
# 239  Activision           0.18    0.18   0.00           0.07    0.43
# 308  Activision           0.11    0.09   0.00           0.04    0.24
# 314  Activision           0.11    0.08   0.00           0.04    0.23

# %%
activision.tail()
# Out:
#                                             Game    Year      Genre  \
# 531        King's Quest: The Complete Collection  2016.0  Adventure
# 603  The Peanuts Movie: Snoopy's Grand Adventure  2015.0   Platform
# 624          Geometry Wars 3: Dimensions Evolved  2016.0     Action
# 755                     The Amazing Spider-Man 2  2014.0       Misc
# 918                   The Legend of Korra (2014)  2014.0     Action
#
#       Publisher  North America  Europe  Japan  Rest of World  Global
# 531  Activision           0.05    0.00    0.0           0.01    0.06
# 603  Activision           0.00    0.03    0.0           0.00    0.03
# 624  Activision           0.02    0.00    0.0           0.01    0.03
# 755  Activision           0.00    0.00    0.0           0.00    0.00
# 918  Activision           0.00    0.00    0.0           0.00    0.00

# %%
plt.subplots(figsize = (10,5))
plt.hist(activision.Game,bins = 40)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(activision.Year,activision['North America'],color = 'red',alpha = 0.5)
plt.xlabel('Year')
plt.ylabel('North America Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(activision.Year,activision['Europe'],color = 'red',alpha = 0.5)
plt.xlabel('Year')
plt.ylabel('Europe Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(activision.Year,activision.Japan,color = 'red',alpha = 0.5)
plt.xlabel('Year')
plt.ylabel('Japan Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(activision.Year,activision.Global,color = 'red',alpha = 0.5)
plt.xlabel('Year')
plt.ylabel('Global Sale')
plt.show()

# %%
sony.head(10)
# Out:
#                            Game    Year             Genre  \
# 6               Uncharted (PS4)  2016.0            Action
# 7              Spider-Man (PS4)  2018.0  Action-Adventure
# 17             God of War (PS4)  2018.0            Action
# 18           Horizon: Zero Dawn  2017.0            Action
# 39           Gran Turismo Sport  2017.0            Racing
# 66       Ratchet & Clank (2016)  2016.0          Platform
# 68   Uncharted: The Lost Legacy  2017.0            Action
# 75        PlayStation VR Worlds  2016.0              Misc
# 99        Detroit: Become Human  2018.0         Adventure
# 114           The Last Guardian  2016.0  Action-Adventure
#
#                           Publisher  North America  Europe  Japan  \
# 6    Sony Interactive Entertainment           4.49    3.93   0.21
# 7    Sony Interactive Entertainment           3.64    3.39   0.32
# 17   Sony Interactive Entertainment           2.83    2.17   0.13
# 18   Sony Interactive Entertainment           2.20    2.43   0.28
# 39   Sony Interactive Entertainment           0.63    2.35   0.24
# 66   Sony Interactive Entertainment           0.97    0.97   0.06
# 68   Sony Interactive Entertainment           0.58    1.38   0.04
# 75   Sony Interactive Entertainment           0.36    1.40   0.09
# 99   Sony Interactive Entertainment           0.55    0.67   0.12
# 114  Sony Interactive Entertainment           0.40    0.58   0.13
#
#      Rest of World  Global
# 6             1.70   10.33
# 7             1.41    8.76
# 17            1.02    6.15
# 18            0.92    5.82
# 39            0.54    3.77
# 66            0.39    2.38
# 68            0.36    2.37
# 75            0.32    2.16
# 99            0.24    1.57
# 114           0.19    1.29

# %%
sony.tail(10)
# Out:
#                                 Game    Year             Genre  \
# 659               Patapon Remastered  2017.0             Music
# 698              LocoRoco Remastered  2017.0          Platform
# 719                  Hustle Kings VR  2016.0            Sports
# 750                      Psychonauts  2017.0            Action
# 759       Uncharted 2: Among Thieves  2016.0            Action
# 760   Uncharted 3: Drake's Deception  2016.0            Action
# 762       Uncharted: Drake's Fortune  2016.0            Action
# 933                             Wild  2019.0         Adventure
# 1013                       Days Gone  2019.0  Action-Adventure
# 1016         The Last of Us: Part II  2019.0            Action
#
#                            Publisher  North America  Europe  Japan  \
# 659   Sony Interactive Entertainment            0.0     0.0   0.02
# 698   Sony Interactive Entertainment            0.0     0.0   0.01
# 719   Sony Interactive Entertainment            0.0     0.0   0.00
# 750   Sony Interactive Entertainment            0.0     0.0   0.00
# 759   Sony Interactive Entertainment            0.0     0.0   0.00
# 760   Sony Interactive Entertainment            0.0     0.0   0.00
# 762   Sony Interactive Entertainment            0.0     0.0   0.00
# 933   Sony Interactive Entertainment            0.0     0.0   0.00
# 1013  Sony Interactive Entertainment            0.0     0.0   0.00
# 1016  Sony Interactive Entertainment            0.0     0.0   0.00
#
#       Rest of World  Global
# 659             0.0    0.02
# 698             0.0    0.01
# 719             0.0    0.00
# 750             0.0    0.00
# 759             0.0    0.00
# 760             0.0    0.00
# 762             0.0    0.00
# 933             0.0    0.00
# 1013            0.0    0.00
# 1016            0.0    0.00

# %%
plt.subplots(figsize = (10,5))
plt.hist(sony.Game,bins = 30)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(sony.Year,sony['North America'],alpha = 0.5,color = 'red')
plt.xlabel('Year')
plt.ylabel('North America Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(sony.Year,sony['Europe'],alpha = 0.5,color = 'red')
plt.xlabel('Year')
plt.ylabel('Europe Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(sony.Year,sony['Japan'],alpha = 0.5,color = 'red')
plt.xlabel('Year')
plt.ylabel('Japan Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(sony.Year,sony['Global'],alpha = 0.5,color = 'red')
plt.xlabel('Year')
plt.ylabel('Global Sale')
plt.show()

# %%
bethesda.head(10)
# Out:
#                                  Game    Year         Genre  \
# 9                           Fallout 4  2015.0  Role-Playing
# 44        The Elder Scrolls V: Skyrim  2016.0  Role-Playing
# 57                        Doom (2016)  2016.0       Shooter
# 79           The Elder Scrolls Online  2015.0           MMO
# 84                       Dishonored 2  2016.0        Action
# 88                    The Evil Within  2014.0        Action
# 98         Wolfenstein: The New Order  2014.0       Shooter
# 110  Wolfenstein II: The New Colossus  2017.0       Shooter
# 130  The Elder Scrolls V: Skyrim PSVR  2017.0  Role-Playing
# 136                The Evil Within II  2017.0        Action
#
#               Publisher  North America  Europe  Japan  Rest of World  Global
# 9    Bethesda Softworks           2.91    3.97   0.27           1.34    8.48
# 44   Bethesda Softworks           1.24    1.50   0.08           0.54    3.36
# 57   Bethesda Softworks           0.93    1.48   0.04           0.46    2.92
# 79   Bethesda Softworks           0.74    0.98   0.00           0.33    2.05
# 84   Bethesda Softworks           0.62    1.02   0.01           0.31    1.97
# 88   Bethesda Softworks           0.56    0.90   0.11           0.28    1.86
# 98   Bethesda Softworks           0.48    0.84   0.03           0.25    1.61
# 110  Bethesda Softworks           0.55    0.58   0.01           0.22    1.36
# 130  Bethesda Softworks           0.47    0.47   0.01           0.19    1.13
# 136  Bethesda Softworks           0.31    0.49   0.09           0.15    1.05

# %%
bethesda.tail(10)
# Out:
#                                     Game    Year         Genre  \
# 110     Wolfenstein II: The New Colossus  2017.0       Shooter
# 130     The Elder Scrolls V: Skyrim PSVR  2017.0  Role-Playing
# 136                   The Evil Within II  2017.0        Action
# 137                          Prey (2017)  2017.0       Shooter
# 207                             DOOM VFR  2017.0       Shooter
# 226           Wolfenstein: The Old Blood  2015.0       Shooter
# 242                           Dishonored  2015.0        Action
# 265    Dishonored: Death of the Outsider  2017.0        Action
# 311  The Elder Scrolls Online: Morrowind  2017.0           MMO
# 445             Wolfenstein The Two Pack  2017.0       Shooter
#
#               Publisher  North America  Europe  Japan  Rest of World  Global
# 110  Bethesda Softworks           0.55    0.58   0.01           0.22    1.36
# 130  Bethesda Softworks           0.47    0.47   0.01           0.19    1.13
# 136  Bethesda Softworks           0.31    0.49   0.09           0.15    1.05
# 137  Bethesda Softworks           0.25    0.62   0.02           0.16    1.04
# 207  Bethesda Softworks           0.22    0.25   0.00           0.09    0.56
# 226  Bethesda Softworks           0.13    0.25   0.02           0.07    0.48
# 242  Bethesda Softworks           0.12    0.21   0.02           0.06    0.42
# 265  Bethesda Softworks           0.10    0.18   0.00           0.05    0.33
# 311  Bethesda Softworks           0.11    0.09   0.00           0.04    0.24
# 445  Bethesda Softworks           0.08    0.00   0.00           0.02    0.10

# %%
plt.subplots(figsize = (10,5))
plt.hist(bethesda.Game,bins = 6)
plt.xticks(rotation = 90)
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(bethesda.Year,bethesda['North America'],alpha = 0.5,color = 'red')
plt.xlabel('Year')
plt.ylabel('North America Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(bethesda.Year,bethesda['Europe'],alpha = 0.5,color = 'red')
plt.xlabel('Year')
plt.ylabel('Europe Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(bethesda.Year,bethesda['Japan'],alpha = 0.5,color = 'red')
plt.xlabel('Year')
plt.ylabel('Japan Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.scatter(bethesda.Year,bethesda['Global'],alpha = 0.5,color = 'red')
plt.xlabel('Year')
plt.ylabel('Global Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.plot(rockstar.Global,rockstar['North America'],color = 'red',label = 'North America')
plt.plot(rockstar.Global,rockstar['Europe'],color = 'green',label = 'Europe')
plt.plot(rockstar.Global,rockstar['Japan'],color = 'blue',label = 'Japan')
plt.legend()
plt.xlabel('Global Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.plot(activision.Global,activision['North America'],color = 'red',label = 'North America')
plt.plot(activision.Global,activision['Europe'],color = 'green',label = 'Europe')
plt.plot(activision.Global,activision['Japan'],color = 'blue',label = 'Japan')
plt.legend()
plt.xlabel('Global Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.plot(sony.Global,sony['North America'],color = 'red',label = 'North America')
plt.plot(sony.Global,sony['Europe'],color = 'green',label = 'Europe')
plt.plot(sony.Global,sony['Japan'],color = 'blue',label = 'Japan')
plt.legend()
plt.xlabel('Global Sale')
plt.show()

# %%
plt.subplots(figsize = (10,5))
plt.plot(bethesda.Global,bethesda['North America'],color = 'red',label = 'North America')
plt.plot(bethesda.Global,bethesda['Europe'],color = 'green',label = 'Europe')
plt.plot(bethesda.Global,bethesda['Japan'],color = 'blue',label = 'Japan')
plt.legend()
plt.xlabel('Global Sale')
plt.show()
